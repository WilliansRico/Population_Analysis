# %%
import pandas as pd
import requests
import time

# ---------------------------------------
# FULL COUNTRY LIST
# ---------------------------------------

countries = [
    ("Afghanistan", "AFG"),
    ("Albania", "ALB"),
    ("Algeria", "DZA"),
    ("American Samoa", "ASM"),
    ("Andorra", "AND"),
    ("Angola", "AGO"),
    ("Antigua and Barbuda", "ATG"),
    ("Argentina", "ARG"),
    ("Armenia", "ARM"),
    ("Aruba", "ABW"),
    ("Australia", "AUS"),
    ("Austria", "AUT"),
    ("Azerbaijan", "AZE"),
    ("Bahamas", "BHS"),
    ("Bahrain", "BHR"),
    ("Bangladesh", "BGD"),
    ("Barbados", "BRB"),
    ("Belarus", "BLR"),
    ("Belgium", "BEL"),
    ("Belize", "BLZ"),
    ("Benin", "BEN"),
    ("Bermuda", "BMU"),
    ("Bhutan", "BTN"),
    ("Bolivia", "BOL"),
    ("Bosnia and Herzegovina", "BIH"),
    ("Botswana", "BWA"),
    ("Brazil", "BRA"),
    ("British Virgin Islands", "VGB"),
    ("Brunei Darussalam", "BRN"),
    ("Bulgaria", "BGR"),
    ("Burkina Faso", "BFA"),
    ("Burundi", "BDI"),
    ("Cabo Verde", "CPV"),
    ("Cambodia", "KHM"),
    ("Cameroon", "CMR"),
    ("Canada", "CAN"),
    ("Cayman Islands", "CYM"),
    ("Central African Republic", "CAF"),
    ("Chad", "TCD"),
    ("Channel Islands", "CHI"),
    ("Chile", "CHL"),
    ("China", "CHN"),
    ("Colombia", "COL"),
    ("Comoros", "COM"),
    ("Democratic Republic of the Congo", "COD"),
    ("Republic of the Congo", "COG"),
    ("Costa Rica", "CRI"),
    ("Cote d'Ivoire", "CIV"),
    ("Croatia", "HRV"),
    ("Cuba", "CUB"),
    ("Curacao", "CUW"),
    ("Cyprus", "CYP"),
    ("Czechia", "CZE"),
    ("Denmark", "DNK"),
    ("Djibouti", "DJI"),
    ("Dominica", "DMA"),
    ("Dominican Republic", "DOM"),
    ("Ecuador", "ECU"),
    ("Egypt", "EGY"),
    ("El Salvador", "SLV"),
    ("Equatorial Guinea", "GNQ"),
    ("Eritrea", "ERI"),
    ("Estonia", "EST"),
    ("Eswatini", "SWZ"),
    ("Ethiopia", "ETH"),
    ("Faroe Islands", "FRO"),
    ("Fiji", "FJI"),
    ("Finland", "FIN"),
    ("France", "FRA"),
    ("French Polynesia", "PYF"),
    ("Gabon", "GAB"),
    ("Gambia, The", "GMB"),
    ("Georgia", "GEO"),
    ("Germany", "DEU"),
    ("Ghana", "GHA"),
    ("Gibraltar", "GIB"),
    ("Greece", "GRC"),
    ("Greenland", "GRL"),
    ("Grenada", "GRD"),
    ("Guam", "GUM"),
    ("Guatemala", "GTM"),
    ("Guinea", "GIN"),
    ("Guinea-Bissau", "GNB"),
    ("Guyana", "GUY"),
    ("Haiti", "HTI"),
    ("Honduras", "HND"),
    ("Hong Kong SAR, China", "HKG"),
    ("Hungary", "HUN"),
    ("Iceland", "ISL"),
    ("India", "IND"),
    ("Indonesia", "IDN"),
    ("Iran", "IRN"),
    ("Iraq", "IRQ"),
    ("Ireland", "IRL"),
    ("Isle of Man", "IMN"),
    ("Israel", "ISR"),
    ("Italy", "ITA"),
    ("Jamaica", "JAM"),
    ("Japan", "JPN"),
    ("Jordan", "JOR"),
    ("Kazakhstan", "KAZ"),
    ("Kenya", "KEN"),
    ("Kiribati", "KIR"),
    ("North Korea", "PRK"),
    ("South Korea", "KOR"),
    ("Kosovo", "XKX"),
    ("Kuwait", "KWT"),
    ("Kyrgyz Republic", "KGZ"),
    ("Lao PDR", "LAO"),
    ("Latvia", "LVA"),
    ("Lebanon", "LBN"),
    ("Lesotho", "LSO"),
    ("Liberia", "LBR"),
    ("Libya", "LBY"),
    ("Liechtenstein", "LIE"),
    ("Lithuania", "LTU"),
    ("Luxembourg", "LUX"),
    ("Macao SAR, China", "MAC"),
    ("Madagascar", "MDG"),
    ("Malawi", "MWI"),
    ("Malaysia", "MYS"),
    ("Maldives", "MDV"),
    ("Mali", "MLI"),
    ("Malta", "MLT"),
    ("Marshall Islands", "MHL"),
    ("Mauritania", "MRT"),
    ("Mauritius", "MUS"),
    ("Mexico", "MEX"),
    ("Micronesia", "FSM"),
    ("Moldova", "MDA"),
    ("Monaco", "MCO"),
    ("Mongolia", "MNG"),
    ("Montenegro", "MNE"),
    ("Morocco", "MAR"),
    ("Mozambique", "MOZ"),
    ("Myanmar", "MMR"),
    ("Namibia", "NAM"),
    ("Nauru", "NRU"),
    ("Nepal", "NPL"),
    ("Netherlands", "NLD"),
    ("New Caledonia", "NCL"),
    ("New Zealand", "NZL"),
    ("Nicaragua", "NIC"),
    ("Niger", "NER"),
    ("Nigeria", "NGA"),
    ("North Macedonia", "MKD"),
    ("Northern Mariana Islands", "MNP"),
    ("Norway", "NOR"),
    ("Oman", "OMN"),
    ("Pakistan", "PAK"),
    ("Palau", "PLW"),
    ("Panama", "PAN"),
    ("Papua New Guinea", "PNG"),
    ("Paraguay", "PRY"),
    ("Peru", "PER"),
    ("Philippines", "PHL"),
    ("Poland", "POL"),
    ("Portugal", "PRT"),
    ("Puerto Rico", "PRI"),
    ("Qatar", "QAT"),
    ("Romania", "ROU"),
    ("Russia", "RUS"),
    ("Rwanda", "RWA"),
    ("Samoa", "WSM"),
    ("San Marino", "SMR"),
    ("Sao Tome and Principe", "STP"),
    ("Saudi Arabia", "SAU"),
    ("Senegal", "SEN"),
    ("Serbia", "SRB"),
    ("Seychelles", "SYC"),
    ("Sierra Leone", "SLE"),
    ("Singapore", "SGP"),
    ("Dutch Sint Maarten", "SXM"),
    ("Republic of Slovakia", "SVK"),
    ("Slovenia", "SVN"),
    ("Solomon Islands", "SLB"),
    ("Somalia", "SOM"),
    ("South Africa", "ZAF"),
    ("South Sudan", "SSD"),
    ("Spain", "ESP"),
    ("Sri Lanka", "LKA"),
    ("St. Kitts and Nevis", "KNA"),
    ("St. Lucia", "LCA"),
    ("French St. Martin", "MAF"),
    ("St. Vincent and the Grenadines", "VCT"),
    ("Sudan", "SDN"),
    ("Suriname", "SUR"),
    ("Sweden", "SWE"),
    ("Switzerland", "CHE"),
    ("Syria", "SYR"),
    ("Tajikistan", "TJK"),
    ("Tanzania", "TZA"),
    ("Thailand", "THA"),
    ("Timor-Leste", "TLS"),
    ("Togo", "TGO"),
    ("Tonga", "TON"),
    ("Trinidad and Tobago", "TTO"),
    ("Tunisia", "TUN"),
    ("Turkiye", "TUR"),
    ("Turkmenistan", "TKM"),
    ("Turks and Caicos Islands", "TCA"),
    ("Tuvalu", "TUV"),
    ("Uganda", "UGA"),
    ("Ukraine", "UKR"),
    ("United Arab Emirates", "ARE"),
    ("United Kingdom", "GBR"),
    ("United States", "USA"),
    ("Uruguay", "URY"),
    ("Uzbekistan", "UZB"),
    ("Vanuatu", "VUT"),
    ("Venezuela", "VEN"),
    ("Vietnam", "VNM"),
    ("American Virgin Islands", "VIR"),
    ("Palestine", "PSE"),
    ("Yemen", "YEM"),
    ("Zambia", "ZMB"),
    ("Zimbabwe", "ZWE")
]

# ---------------------------------------
# MANUAL OVERRIDES
# ---------------------------------------

manual_overrides = {
    "XKX": {
        "capital": "Pristina",
        "continent": "Europe",
        "land_area_km2": 10887
    },
    "CHI": {
        "capital": "Saint Peter Port",
        "continent": "Europe",
        "land_area_km2": 198
    },
    "AZE": {
        "capital": "Baku",
        "continent": "Asia",
        "land_area_km2": 86600
    },
    "TUR": {
        "capital": "Ankara",
        "continent": "Asia",
        "land_area_km2": 783562
    },
    "MAC": {
        "capital": "Macau",
        "continent": "Asia",
        "land_area_km2": 30
    },
    "GNQ": {
        "capital": "Malabo",
        "continent": "Africa",
        "land_area_km2": 28051}
        
}

# ---------------------------------------
# FETCH DATA
# ---------------------------------------

records = []

for country_name, code in countries:

    print(f"Processing {country_name} ({code})")

    if code in manual_overrides:

        override = manual_overrides[code]

        records.append({
            "country_code": code,
            "country_name": country_name,
            "capital": override["capital"],
            "land_area_km2": override["land_area_km2"],
            "continent": override["continent"]
        })

        continue

    url = f"https://restcountries.com/v3.1/alpha/{code}"

    try:

        response = requests.get(url, timeout=20)

        if response.status_code != 200:

            print(f"Failed: {country_name}")
            continue

        data = response.json()[0]

        capital = None

        if data.get("capital"):
            capital = data["capital"][0]

        continent = None

        if data.get("continents"):
            continent = data["continents"][0]

        area = data.get("area")

        records.append({
            "country_code": code,
            "country_name": country_name,
            "capital": capital,
            "land_area_km2": int(area) if area else None,
            "continent": continent
        })

        time.sleep(0.15)

    except Exception as e:

        print(f"ERROR {country_name}: {e}")

# ---------------------------------------
# FINAL DATAFRAME
# ---------------------------------------

final_df = pd.DataFrame(records)

final_df = final_df.sort_values("country_name")

# ---------------------------------------
# EXPORT
# ---------------------------------------

final_df.to_csv(
    "country_enrichment.csv",
    index=False,
    encoding="utf-8"
)

# ---------------------------------------
# PRINT FULL OUTPUT
# ---------------------------------------

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

print(final_df.to_string(index=False))

print("\\nCSV exported successfully.")
# Out:
# Processing Afghanistan (AFG)
# Processing Albania (ALB)
# Processing Algeria (DZA)
# Processing American Samoa (ASM)
# Processing Andorra (AND)
# Processing Angola (AGO)
# Processing Antigua and Barbuda (ATG)
# Processing Argentina (ARG)
# Processing Armenia (ARM)
# Processing Aruba (ABW)
# Processing Australia (AUS)
# Processing Austria (AUT)
# Processing Azerbaijan (AZE)
# Processing Bahamas (BHS)
# Processing Bahrain (BHR)
# Processing Bangladesh (BGD)
# Processing Barbados (BRB)
# Processing Belarus (BLR)
# Processing Belgium (BEL)
# Processing Belize (BLZ)
# Processing Benin (BEN)
# Processing Bermuda (BMU)
# Processing Bhutan (BTN)
# Processing Bolivia (BOL)
# Processing Bosnia and Herzegovina (BIH)
# Processing Botswana (BWA)
# Processing Brazil (BRA)
# Processing British Virgin Islands (VGB)
# Processing Brunei Darussalam (BRN)
# Processing Bulgaria (BGR)
# Processing Burkina Faso (BFA)
# Processing Burundi (BDI)
# Processing Cabo Verde (CPV)
# Processing Cambodia (KHM)
# ...
